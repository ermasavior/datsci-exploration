# %% [markdown]
# # W09 - Association Rule
# In this hands-on session, we will try to uncover the association rule from given transaction items. Association rule mining is a technique to identify underlying relations between different items. We will cover:
# 1. data preprocessing for association rule,
# 2. implement algorithm for association rule,
# 3. find interesting association rule from dataset

# %% [markdown]
# ## Read dataset "dataset_association_rule.dat"
# Download the dataset "dataset_association_rule.dat" in the course portal "IF4041 Ilmu Data dan Penggalian Data".

# %%
import numpy as np
import pandas as pd

df = pd.read_csv('dataset_association_rule.dat', header=None)
df.head()
# Out:
#                                                    0
# 0  36 69 115 226 278 343 345 358 368 370 401 450 ...
# 1  8 51 55 73 78 117 140 175 187 229 266 295 304 ...
# 2  53 55 98 159 192 322 332 402 412 413 424 430 4...
# 3  48 203 205 227 279 294 320 335 359 414 509 525...
# 4  58 69 73 82 120 146 166 178 217 220 244 256 33...

# %% [markdown]
# ## Question 01 (Q01)
# Based on dataset that given to you, implement several data pre-processing process. <b>Note :</b> you should taylor the data pre-processing step based on algorithm and library that you used in this hands-on. Save the result of data pre-processing in variable called 'item_belanja'.<br>

# %%
dataset = df.values.tolist()
for row in dataset:
    item_belanja.append(row[0].split())

# %% [markdown]
# Print the pre-processing result :

# %%
item_belanja
# Out:
# [['36',
#   '69',
#   '115',
#   '226',
#   '278',
#   '343',
#   '345',
#   '358',
#   '368',
#   '370',
#   '401',
#   '450',
#   '489',
#   '494',
#   '573',
#   '577',
#   '581',
#   '583',
#   '610',
#   '682',
#   '692',
#   '705',
#   '722',
#   '832',
#   '862',
#   '886',
#   '908',
#   '923',
#   '932',
#   '960',
#   '977'],
#  ['8',
#   '51',
#   '55',
#   '73',
#   '78',
#   '117',
#   '140',
#   '175',
#   '187',
#   '229',
#   '266',
#   '295',
#   '304',
#   '366',
#   '381',
#   '413',
#   '424',
#   '429',
#   '501',
#   '512',
#   '523',
#   '529',
#   '538',
#   '572',
#   '575',
#   '576',
#   '593',
#   '675',
#   '676',
#   '688',
#   '735',
#   '758',
#   '785',
#   '797',
#   '812',
#   '823',
#   '826',
#   '843',
#   '854',
#   '868',
#   '871',
#   '888',
#   '893',
#   '956',
#   '982'],
#  ['53',
#   '55',
#   '98',
#   '159',
#   '192',
#   '322',
#   '332',
#   '402',
#   '412',
#   '413',
#   '424',
#   '430',
#   '450',
#   '480',
#   '526',
# ...

# %% [markdown]
# Praproses data menggunakan `TransactionEncoder`

# %%
from mlxtend.frequent_patterns import apriori

te_ary = te.fit(item_belanja).transform(item_belanja)
preprocessed_df = pd.DataFrame(te_ary, columns=te.columns_)
preprocessed_df
# Out:
#             0      1     10    100    101    102    103    104    105    106  \
# 0       False  False  False  False  False  False  False  False  False  False
# 1       False  False  False  False  False  False  False  False  False  False
# 2       False  False  False  False  False  False  False  False  False  False
# 3       False  False  False  False  False  False  False  False  False  False
# 4       False  False  False  False  False  False  False  False  False  False
# ...       ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 299995  False  False  False  False  False  False  False  False  False  False
# 299996  False  False  False  False  False  False  False  False  False  False
# 299997  False  False  False  False  False  False  False  False  False  False
# 299998  False  False  False  False  False  False  False  False  False  False
# 299999  False  False  False  False  False  False  False  False  False  False
#
# ...

# %% [markdown]
# ## Question 02 (Q02)
# In this step, you will generate association rule from this dataset.<br><br>
# a. Choose the library that you will use for generating association rule, and give explanation about why you choose that library and what is the algorithm used in that library<br>
# b. Using the library that you've chosen in (Q02.a), generate association rules from the pre-processed dataset in Q01.<br>
# c. Print the association rule that you have find in Q02.b along with its support and confidence.<br>
# d. What is your conclusion from association rule that you have uncover before ?

# %% [markdown]
# Your Answer (Q02.a):
#
# Association rule generation menggunakan library [**MLextend**](http://rasbt.github.io/mlxtend/user_guide/frequent_patterns/apriori/#frequent-itemsets-via-apriori-algorithm)
# karena library yang disediakan beserta dokumentasinya lengkap, terstruktur, dan mudah dipelajari.

# %% [markdown]
# Pembangkitan frequent itemsets menggunakan fpgrowth

# %%
from mlxtend.frequent_patterns import fpgrowth
from mlxtend.frequent_patterns import association_rules

frequent_itemsets = fpgrowth(preprocessed_df, min_support=0.01)
frequent_itemsets
# Out:
#        support    itemsets
# 0      0.28738       (282)
# 1      0.18921       (407)
# 2      0.17427       (610)
# 3      0.17203       (621)
# 4      0.16203       (654)
# ...        ...         ...
# 65231  0.01184   (25, 852)
# 65232  0.01381  (852, 878)
# 65233  0.01091  (852, 126)
# 65234  0.01043  (329, 171)
# 65235  0.01041  (395, 431)
#
# [65236 rows x 2 columns]

# %%
rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.3)
rules
# Out:
#         antecedents consequents  antecedent support  consequent support  \
# 0             (407)       (282)             0.18921             0.28738
# 1        (126, 407)       (282)             0.03695             0.28738
# 2        (126, 407)       (450)             0.03695             0.23384
# 3        (336, 407)       (282)             0.03347             0.28738
# 4        (763, 407)       (282)             0.03915             0.28738
# ...             ...         ...                 ...                 ...
# 3941189       (533)       (450)             0.01558             0.23384
# 3941190       (852)       (398)             0.04360             0.13540
# 3941191       (852)       (878)             0.04360             0.16311
# 3941192       (171)       (329)             0.01165             0.06191
# 3941193       (395)       (431)             0.02525             0.20125
#
#          support  confidence       lift  leverage  conviction
# ...

# %%
rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.99)
rules
# Out:
#                          antecedents consequents  antecedent support  \
# 0               (450, 259, 636, 330)       (146)             0.01033
# 1          (450, 259, 228, 330, 636)       (146)             0.01011
# 2          (737, 450, 259, 228, 330)       (146)             0.01014
# 3               (737, 330, 259, 636)       (146)             0.01037
# 4               (636, 737, 259, 228)       (146)             0.01035
# ...                              ...         ...                 ...
# 20222       (503, 209, 83, 407, 185)       (741)             0.01253
# 20223           (641, 185, 209, 503)       (741)             0.01276
# 20224       (641, 209, 83, 503, 185)       (741)             0.01259
# 20225      (641, 503, 209, 407, 185)       (741)             0.01250
# 20226  (641, 503, 209, 83, 407, 185)       (741)             0.01233
#
#        consequent support  support  confidence      lift  leverage  conviction
# ...

# %% [markdown]
# Your Conclusion (Q02.d):
#
# Dari percobaan men-generate frequent_itemsets dengan minimum support **0.01** dengan minimum threshold **0.99**, dihasilkan sebanyak 20227 rule.
#
# Pada frequent itemsets, semakin kecil nilai minimum support, semakin banyak frequent itemset yang dihasilkan.
#
# Pada association rules, semakin kecil nilai minimum threshold, semakin sedikit rules yang dihasilkan.
